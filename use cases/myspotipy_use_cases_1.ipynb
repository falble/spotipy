# %% [markdown]
# # myspotipy
#
# This notebook contains some use cases involving the uploaded functions.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="YOUR_APP_CLIENT_ID",
                                                           client_secret="YOUR_APP_CLIENT_SECRET"))

# %% [markdown]
# ## list_single
# - This is a basic function that lists all the uploaded singles for a specific artist

# %%
def list_single(uri):
    """ Listing all the online singles for an URI
    
    Parameters
    ----------
    uri : str
        uri of the artist
        'spotify:artist:INSERT_HERE_SPECIFIC_URI_CODE'

    Returns
    -------
    None.
    
    """
    artist = sp.artist(uri)
    print('ARTIST: ',artist['name'])
    print('GENRES: ',artist['genres'])
    print('POPULARITY: ',artist['popularity'])
    print('ACTUAL FOLLOWERS: ',artist['followers'])
    print('uri: ',artist['uri'])
    print('external_urls: ',artist['external_urls'],'\n')
    
    results = sp.artist_albums(uri, album_type='single')
    albums = results['items']
    name = []
    release_date = []
    total_tracks = []
    
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    
    print('SINGLES UPLOADED:\n')
    
    for album in albums:
        name.append(album['name'])
        release_date.append(album['release_date'])
        total_tracks.append(album['total_tracks'])
    
    col = ['name','release_date','total_tracks']
    df = pd.DataFrame(list(zip(name,release_date,total_tracks)),columns=col).drop_duplicates(subset='name')
    print(df)
    
    print('\n---------------------------------------------------------------------------------\n')
        
    return None

# %%
# arctic example
list_single('spotify:artist:7Ln80lUS6He07XvHI8qqHH')
# Out:
# ARTIST:  Arctic Monkeys
# GENRES:  ['garage rock', 'modern rock', 'permanent wave', 'rock', 'sheffield indie']
# POPULARITY:  86
# ACTUAL FOLLOWERS:  {'href': None, 'total': 10384940}
# uri:  spotify:artist:7Ln80lUS6He07XvHI8qqHH
# external_urls:  {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'}
#
# SINGLES UPLOADED:
#
#                                            name release_date  total_tracks
# 0      Arabella (Live At The Royal Albert Hall)   2020-12-02             2
# 1           505 (Live At The Royal Albert Hall)   2020-11-19             1
# 2               Tranquility Base Hotel & Casino   2018-05-02             2
# 4                               Spotify Singles   2018-05-01             2
# 6                              One For The Road   2013-12-09             2
# 7      Why'd You Only Call Me When You're High?   2013-09-02             2
# 8                              Do I Wanna Know?   2013-07-18             2
# 13                      R U Mine? / Electricity   2012-04-24             2
# 15                                Black Treacle   2012-01-23             2
# 17                                    R U Mine?   2012-01-01             2
# 19                              Suck It and See   2011-11-01             2
# 21               The Hellcat Spangled Shalalala   2011-08-16             2
# 23  Don't Sit Down 'Cause I've Moved Your Chair   2011-05-31             3
# 25                                 My Propeller   2010-03-23             4
# 27                                  Cornerstone   2009-11-17             4
# 29                             Crying Lightning   2009-08-18             3
# 31                                 Teddy Picker   2007-12-25             4
# 33                       Fluorescent Adolescent   2007-09-11             4
# 35                        Da Frame 2R / Matador   2007-06-18             2
# 36                                   Brianstorm   2007-04-15             4
# 39              Leave Before The Lights Come On   2006-10-31             3
# 41             Who The F*** Are Arctic Monkeys?   2006-05-09             5
# 43                       When The Sun Goes Down   2006-02-21             4
# 46        I Bet You Look Good On The Dancefloor   2005-11-29             3
# 48             Five Minutes With Arctic Monkeys   2005-05-30             2
#
# ---------------------------------------------------------------------------------

# %%
# razorbacks example
list_single('spotify:artist:3zAvbJuxv6xgNuROqGSmUA')
# Out:
# ARTIST:  The Razorbacks
# GENRES:  []
# POPULARITY:  0
# ACTUAL FOLLOWERS:  {'href': None, 'total': 5}
# uri:  spotify:artist:3zAvbJuxv6xgNuROqGSmUA
# external_urls:  {'spotify': 'https://open.spotify.com/artist/3zAvbJuxv6xgNuROqGSmUA'}
#
# SINGLES UPLOADED:
#
#         name release_date  total_tracks
# 0         BB   2015-12-25             1
# 1  Sometimes   2015-09-27             4
# 2    Outlook   2013-11-07             2
#
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## list_album
# - This is a basic function that lists all the uploaded albums for a specific artist.

# %%
def list_album(uri):
    """ Listing all the online albums for an artist
    
    Parameters
    ----------
    uri : str
        uri of the artist.
        'spotify:artist:INSERT_HERE_SPECIFIC_URI_CODE'

    Returns
    -------
    None.

    """
    artist = sp.artist(uri)
    print('ARTIST: ',artist['name'])
    print('GENRES: ',artist['genres'])
    print('POPULARITY: ',artist['popularity'])
    print('ACTUAL FOLLOWERS: ',artist['followers'])
    print('uri: ',artist['uri'])
    print('external_urls: ',artist['external_urls'],'\n')
   
    results = sp.artist_albums(uri, album_type='album')
    albums = results['items']
    name = []
    release_date = []
    total_tracks = []
    
    
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    
    print('ALBUM:\n')
    
    for album in albums:
        name.append(album['name'])
        release_date.append(album['release_date'])
        total_tracks.append(album['total_tracks'])
    
    col = ['name','release_date','total_tracks']
    df = pd.DataFrame(list(zip(name,release_date,total_tracks)),columns=col).drop_duplicates(subset=['release_date'],keep='first')
    print(df)
    
    print('\n---------------------------------------------------------------------------------------------\n')
    
    return None

# %%
# green day example
list_album('spotify:artist:7oPftvlwr6VrsViSDV7fJY')
# Out:
# ARTIST:  Green Day
# GENRES:  ['permanent wave', 'pop punk', 'punk']
# POPULARITY:  82
# ACTUAL FOLLOWERS:  {'href': None, 'total': 11487879}
# uri:  spotify:artist:7oPftvlwr6VrsViSDV7fJY
# external_urls:  {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'}
#
# ALBUM:
#
#                                  name release_date  total_tracks
# 0                      No Fun Mondays   2020-11-27            14
# 1                    Father of All...   2020-02-07            10
# 2                    Revolution Radio   2016-10-07            12
# 3                         Demolicious   2014-04-19            18
# 4                               ¡TRÉ!   2012-12-11            12
# 6                               ¡DOS!   2012-11-13            13
# 7                               ¡DOS!   2012-11-12            13
# 8                               ¡UNO!   2012-09-24            12
# 11             21st Century Breakdown   2009-05-15            20
# 17            American Idiot (Deluxe)   2004-09-21            12
# 19                        Shenanigans   2002-07-02            14
# 20                            Warning   2000-10-03            12
# 21                             Nimrod   1997-10-14            18
# 22                     Unplugged 1996         1996            23
# 23                          Insomniac   1995-10-10            14
# 24                             Dookie   1994-02-01            15
# 25                          Kerplunk!   1992-01-17            16
# 27  1,039 / Smoothed out Slappy Hours   1991-07-01            23
#
# ---------------------------------------------------------------------------------------------

# %%
# dire straits example
list_album('https://open.spotify.com/artist/0WwSkZ7LtFUFjGjMZBMt6T')
# Out:
# ARTIST:  Dire Straits
# GENRES:  ['album rock', 'classic rock', 'mellow gold', 'rock', 'soft rock']
# POPULARITY:  77
# ACTUAL FOLLOWERS:  {'href': None, 'total': 4171858}
# uri:  spotify:artist:0WwSkZ7LtFUFjGjMZBMt6T
# external_urls:  {'spotify': 'https://open.spotify.com/artist/0WwSkZ7LtFUFjGjMZBMt6T'}
#
# ALBUM:
#
#                           name release_date  total_tracks
# 0              Live At The BBC   1995-06-26             8
# 2                 On the Night   1993-05-10            10
# 4              On Every Street   1991-09-10            12
# 6             Brothers In Arms   1985-05-13             9
# 9   Alchemy: Dire Straits Live   1984-03-14            11
# 10              Love Over Gold   1982-09-20             5
# 12               Making Movies   1980-10-17             7
# 14                  Communiqué   1979-06-15             9
# 16                Dire Straits   1978-10-07             9
#
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# ## list_album_tracks
# - This is a basic function that lists the tracks for a specific album.

# %%
def list_album_tracks(uri):
    """ List all the tracks for an album

    Parameters
    ----------
    uri : str
        uri/url of the album
        'spotify:artist:INSERT_HERE_SPECIFIC_URI_CODE'

    Returns
    -------
    None.

    """
    album = sp.album(uri)

    print('ALBUM NAME: ',album['name'])
    print('ARTIST: ',album['artists'][0]['name'])
    print('TYPE: ',album['album_type'])
    print('RELEASE DATE: ',album['release_date'])
    print('POPULARITY: ',album['popularity'],'\n')
    
    album_tracks = sp.album_tracks(uri)
    
    print('TRACKS: \n')
    
    for i in range(len(album_tracks['items'])):
        print('({}):'.format(i+1),album_tracks['items'][i]['name'])
     
    print('\n---------------------------------------------------------------------------------\n')   
     
    return None

# %%
# Whatever People Say I Am, That's What I'm Not example
list_album_tracks('https://open.spotify.com/album/50Zz8CkIhATKUlQMbHO3k1')
# Out:
# ALBUM NAME:  Whatever People Say I Am, That's What I'm Not
# ARTIST:  Arctic Monkeys
# TYPE:  album
# RELEASE DATE:  2006-01-29
# POPULARITY:  77
#
# TRACKS:
#
# (1): The View From The Afternoon
# (2): I Bet You Look Good On The Dancefloor
# (3): Fake Tales Of San Francisco
# (4): Dancing Shoes
# (5): You Probably Couldn't See For The Lights But You Were Staring Straight At Me
# (6): Still Take You Home
# (7): Riot Van
# (8): Red Light Indicates Doors Are Secured
# (9): Mardy Bum
# (10): Perhaps Vampires Is A Bit Strong But…
# (11): When The Sun Goes Down
# (12): From The Ritz To The Rubble
# (13): A Certain Romance
#
# ---------------------------------------------------------------------------------

# %%
# Game of Thrones (Music from the HBO® Series - Season 6) example
list_album_tracks('https://open.spotify.com/album/7bBlW6L9r3ICFkbf2WRDXL')
# Out:
# ALBUM NAME:  Game of Thrones (Music from the HBO® Series - Season 6)
# ARTIST:  Ramin Djawadi
# TYPE:  album
# RELEASE DATE:  2016-06-24
# POPULARITY:  64
#
# TRACKS:
#
# (1): Main Titles
# (2): Blood of My Blood
# (3): Light of the Seven
# (4): Needle
# (5): Coronation
# (6): Feed the Hounds
# (7): My Watch Has Ended
# (8): The Red Woman
# (9): Hold the Door
# (10): Khaleesi
# (11): Maester
# (12): A Painless Death
# (13): Reign
# (14): Let's Play a Game
# (15): Bastard
# (16): Trust Each Other
# (17): Winter Has Come
# (18): Hear Me Roar
# (19): The Winds of Winter
# (20): Lord of Light (Bonus Track)
# (21): Service of the Gods (Bonus Track)
# (22): I Need You by My Side (Bonus Track)
# (23): The Tower (Bonus Track)
# (24): Unbowed, Unbent, Unbroken (Bonus Track)
# (25): I Choose Violence (Bonus Track)
# (26): Hodor (Bonus Track)
#
# ---------------------------------------------------------------------------------

# %%
# Dookie example
list_album_tracks('https://open.spotify.com/album/4uG8q3GPuWHQlRbswMIRS6')
# Out:
# ALBUM NAME:  Dookie
# ARTIST:  Green Day
# TYPE:  album
# RELEASE DATE:  1994-02-01
# POPULARITY:  78
#
# TRACKS:
#
# (1): Burnout
# (2): Having a Blast
# (3): Chump
# (4): Longview
# (5): Welcome to Paradise
# (6): Pulling Teeth
# (7): Basket Case
# (8): She
# (9): Sassafras Roots
# (10): When I Come Around
# (11): Coming Clean
# (12): Emenius Sleepus
# (13): In the End
# (14): F.O.D.
# (15): All by Myself
#
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## playlist_to_df
# - This function takes as input the identifier of a playlist and returns it as a pandas DataFrame

# %%
def playlist_to_df(uri):
    """ transforming a playlist into a df (max 595 songs)
    

    Parameters
    ----------
    uri : str
        uri/url of the album
        'spotify:artist:INSERT_HERE_SPECIFIC_URI_CODE'

    Returns
    -------
    df : pd.DataFrame
        DataFrame of the playlist in order to perform some actions

    """
    playlist_1 = sp.playlist(uri)
    playlist_2 = sp.playlist_items(uri,limit=None,offset=0)
    playlist_3 = sp.playlist_items(uri,limit=None,offset=99)
    playlist_4 = sp.playlist_items(uri,limit=None,offset=198)
    playlist_5 = sp.playlist_items(uri,limit=None,offset=297)
    playlist_6 = sp.playlist_items(uri,limit=None,offset=396)
    playlist_7 = sp.playlist_items(uri,limit=None,offset=495)
    
    all_playlist = [playlist_2, playlist_3, playlist_4, playlist_5, playlist_6, playlist_7]
    
    print('name: ', playlist_1['name'])
    print('public: ',playlist_1['public'])
    print('collaborative: ',playlist_1['collaborative'])
    print('description: ',playlist_1['description'])
    print('followers: ', playlist_1['followers']['total'])
    print('\n---------------------------------------------------------------------------------\n')
    
    artist_name = []
    album_name = []
    track_name = []
    track_number = []
    popularity = []
    uris = []
    col = ['artist','album','track_name','track_number','popularity','uri']
    
    for playlist in all_playlist:
        if playlist != 0:
            for i in range(len(playlist['items'])):
                artist_name.append(playlist['items'][i]['track']['artists'][0]['name'])
                album_name.append(playlist['items'][i]['track']['album']['name'])
                track_name.append(playlist['items'][i]['track']['name'])
                track_number.append(playlist['items'][i]['track']['track_number'])
                popularity.append(playlist['items'][i]['track']['popularity'])
                uris.append(playlist['items'][i]['track']['artists'][0]['uri'])
        else:
            pass
    

    df = pd.DataFrame(list(zip(artist_name,album_name,track_name,track_number,popularity,uris)), columns=col)
    
    print('<DataFrame completed>')
    print('\n---------------------------------------------------------------------------------\n')
        
    return df

# %%
# pyhton example
df_1 = playlist_to_df('https://open.spotify.com/playlist/4KVBI6CgDDldQGlQ5BihaU')
df_1
# Out:
# name:  python
# public:  True
# collaborative:  False
# description:  Number of different artists: 96
# followers:  6
#
# ---------------------------------------------------------------------------------
#
# <DataFrame completed>
#
# ---------------------------------------------------------------------------------
#            artist                                              album  \
# 0         Santana                                            Abraxas
# 1         Santana                                            Abraxas
# 2         Santana                                            Abraxas
# 3         Santana                                            Abraxas
# 4         Santana                                            Santana
# ..            ...                                                ...
# 219      Babybird                                   Best of Babybird
# 220     The Doors                                     Morrison Hotel
# 221   Hans Zimmer  Sherlock Holmes (Original Motion Picture Sound...
# 222   Hans Zimmer  Sherlock Holmes (Original Motion Picture Sound...
# 223  Sly & Robbie                                      Reggae Greats
#
#                           track_name  track_number  popularity  \
# 0    Black Magic Woman / Gypsy Queen             2          59
# 1                        Oye Como Va             3          66
# 2                        Samba Pa Ti             7          64
# 3         Hope You're Feeling Better             8          46
# 4                            Waiting             1          36
# ..                               ...           ...         ...
# 219                  You're Gorgeous             1          46
# 220                  Roadhouse Blues             1          71
# 221     My Mind Rebels At Stagnation             4          38
# 222                   Discombobulate             1          54
# 223             Computer Malfunction             5          18
#
#                                        uri
# 0    spotify:artist:6GI52t8N5F02MxU0g5U69P
# 1    spotify:artist:6GI52t8N5F02MxU0g5U69P
# 2    spotify:artist:6GI52t8N5F02MxU0g5U69P
# 3    spotify:artist:6GI52t8N5F02MxU0g5U69P
# 4    spotify:artist:6GI52t8N5F02MxU0g5U69P
# ..                                     ...
# 219  spotify:artist:1QCANeffsBIHjzhMqUIxBh
# 220  spotify:artist:22WZ7M8sxp5THdruNY3gXt
# 221  spotify:artist:0YC192cP3KPCRWx8zr8MfZ
# 222  spotify:artist:0YC192cP3KPCRWx8zr8MfZ
# 223  spotify:artist:6jJG408jz8VayohX86nuTt
#
# [224 rows x 6 columns]

# %%
print('Number of different artists: ',len(set(df_1.artist)))
# Out:
# Number of different artists:  96

# %%
df_1_artists = list(set(df_1.artist))
df_1_artists.sort(reverse=False)
print('List of artists: ',df_1_artists)
print('\n---------------------------------------------------------------------------------\n')
# Out:
# List of artists:  ['Antonio Vivaldi', 'Arctic Monkeys', 'Babybird', 'Barry McGuire', 'Blonde Redhead', 'Bob Dylan', 'Bobby McFerrin', 'Chuck Berry', 'Count Five', 'Cream', 'Creedence Clearwater Revival', 'Crumb', 'Daft Punk', 'David Bowie', 'Deep Purple', 'Derek & The Dominos', 'Dire Straits', 'Dr. Feelgood', 'Eagles', 'Eddy Grant', 'Einzelkind', 'Eric Clapton', 'FantomenK', 'Frank Zappa', 'Geek Music', 'Giuseppe Verdi', 'Gorillaz', 'Grateful Dead', 'Green Day', 'Guy Lombardo', 'Hans Zimmer', 'Harry Gregson-Williams', 'Hayze', 'Hello World', 'Hugh Laurie', 'Hyper', 'I Monster', 'Iggy Pop', 'Jefferson Airplane', 'Jerry Reed', 'Jimi Hendrix', 'John Lennon', 'Johnny Cash', 'Johnny Wright', 'Kanye West', 'Kings of Convenience', 'Led Zeppelin', 'Leonard Cohen', 'Lou Reed', 'Ludwig van Beethoven', 'Lynyrd Skynyrd', 'Mac Quayle', 'Massive Attack', 'Master KG', 'Mattafix', 'Maxence Cyrin', 'Mazzy Star', 'MoodBlast', 'Moodymann', 'Movie Sounds Unlimited', 'Myuu', 'Nada', 'Neil Young', 'Nirvana', 'Oasis', 'Pink Floyd', 'Pixies', 'Queen', 'Ramin Djawadi', 'Rick and Morty', 'Rod Stewart', 'Salmo', 'Santana', 'Sly & Robbie', 'Stealers Wheel', 'Steppenwolf', 'Stevie Wonder', 'Supergrass', 'The Animals', 'The Beach Boys', 'The Beatles', 'The Doobie Brothers', 'The Doors', 'The Highwaymen', 'The Network', 'The Rolling Stones', 'The Trashmen', 'The Velvet Underground', 'Three Dog Night', 'Tracy Chapman', 'Traffic', 'Trent Reznor and Atticus Ross', 'Vicetone', 'Yusuf / Cat Stevens', 'ZZ Top', 'alt-J']
#
# ---------------------------------------------------------------------------------

# %%
# save a txt file in the same folder with these information, it can be used for playlist description

#with open('playlist_df_1.txt','w',encoding="utf-8") as txt:
#    txt.write('Number of different artists: '+str(len(set(df_1.artist)))+'-------- \n')
#    for element in df_1_artists:
#        txt.write('%s'%element+'/')

# %% [markdown]
# ## playlist_to_artists_df
# - This function takes as input the identifier of a playlist and returns a pandas DataFrame containing the set of artists and their identifier in order to have a DataFrame to perform other operations.

# %%
def playlist_to_artists_df(uri):
    """ transforming a playlist into a df of artists and uris (max 595 songs)
    

    Parameters
    ----------
    uri : str
        uri/url of the album
        'spotify:artist:INSERT_HERE_SPECIFIC_URI_CODE'

    Returns
    -------
    df : pd.DataFrame
        DataFrame of the playlist in order to perform some actions

    """
    playlist_1 = sp.playlist(uri)
    playlist_2 = sp.playlist_items(uri,limit=None,offset=0)
    playlist_3 = sp.playlist_items(uri,limit=None,offset=99)
    playlist_4 = sp.playlist_items(uri,limit=None,offset=198)
    playlist_5 = sp.playlist_items(uri,limit=None,offset=297)
    playlist_6 = sp.playlist_items(uri,limit=None,offset=396)
    playlist_7 = sp.playlist_items(uri,limit=None,offset=495)
    
    all_playlist = [playlist_2, playlist_3, playlist_4, playlist_5, playlist_6, playlist_7]
    
    print('name: ', playlist_1['name'])
    print('public: ',playlist_1['public'])
    print('collaborative: ',playlist_1['collaborative'])
    print('description: ',playlist_1['description'])
    print('followers: ', playlist_1['followers']['total'])
    print('\n---------------------------------------------------------------------------------\n')
    
    artist_name = []
    uris = []
    col = ['artist','uri']
    
    for playlist in all_playlist:
        if playlist != 0:
            for i in range(len(playlist['items'])):
                artist_name.append(playlist['items'][i]['track']['artists'][0]['name'])
                uris.append(playlist['items'][i]['track']['artists'][0]['uri'])
        else:
            pass
    

    df = pd.DataFrame(list(zip(artist_name,uris)), columns=col).drop_duplicates(subset=['uri'],keep='first')
    
    print('<DataFrame completed>')
    print('\n---------------------------------------------------------------------------------\n')
        
    return df

# %%
# the adults are talking example
df_1 = playlist_to_artists_df('https://open.spotify.com/playlist/2rQTtxMfmdrQOWHeEbStwM')
df_1
# Out:
# name:  the adults are talking
# public:  True
# collaborative:  False
# description:  You are saying all the words I&#x27;m dreaming--------Number of different artists: 72
# followers:  7
#
# ---------------------------------------------------------------------------------
#
# <DataFrame completed>
#
# ---------------------------------------------------------------------------------
#                   artist                                    uri
# 0         Arctic Monkeys  spotify:artist:7Ln80lUS6He07XvHI8qqHH
# 2      Cage The Elephant  spotify:artist:26T3LtbuGT1Fu9m0eRq5X3
# 4               The Cure  spotify:artist:7bu3H8JO7d0UbMoVzbo70s
# 5           Joy Division  spotify:artist:432R46LaYsJZV2Gmc4jUV5
# 6                   MGMT  spotify:artist:0SwO7SWeDHJijQ3XNS7xEE
# ..                   ...                                    ...
# 250        Alkaline Trio  spotify:artist:1aEYCT7t18aM3VvM6y8oVR
# 252          Against Me!  spotify:artist:29lz7gs8edwnnfuXW4FhMl
# 264  The Gaslight Anthem  spotify:artist:7If8DXZN7mlGdQkLE2FaMo
# 265   The Rolling Stones  spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# 266         Rino Gaetano  spotify:artist:5RRPSRJpISAWEPOeSfYuhV
#
# [72 rows x 2 columns]

# %%
print('Number of different artists: ',len(set(df_1.artist)))
# Out:
# Number of different artists:  72

# %% [markdown]
# - so, once this function created the DataFrame we can perform other operation like suggesting artists starting with those contained in the playlist, using spotify information.

# %% [markdown]
# ## artist_df_suggested_artists_df
# - This function takes as input a DataFrame, that needs to contain the identifier of the artists, and returns another DataFrame that contains the information regarding the suggested artists.

# %%
def artist_df_suggested_artists_df(df):
    """ From a df containing the information of a playlist, this function, suggests for the 15 most featured 
    artists a dataframe of related artists according to spotify.  similarity is based on analysis of the 
    spotify community’s listening history.

    df : pd.DataFrame (containing the columns 'artist' & 'uri')
        iterable containing the uris/urls of the artists
        'spotify:artist:INSERT_HERE_SPECIFIC_URI_CODE'

    Returns
    -------
    rel_df : pd.DataFrame
        DataFrame of the suggested artists in order to perform some actions

    """
    most_frequent = df['uri'].value_counts().head(15).to_frame('uri').index
    
    rel_name = []
    rel_genres = []
    rel_uri = []
    rel_pop = []
    rel_col = ['name','genres','uri','popularity']
    
    for uri in most_frequent:
        for i in range(len(sp.artist_related_artists(uri)['artists'])):
            rel_name.append(sp.artist_related_artists(uri)['artists'][i]['name'])
            rel_genres.append(sp.artist_related_artists(uri)['artists'][i]['genres'])
            rel_uri.append(sp.artist_related_artists(uri)['artists'][i]['uri'])
            rel_pop.append(sp.artist_related_artists(uri)['artists'][i]['popularity'])
            
    rel_df = pd.DataFrame(list(zip(rel_name,rel_genres,rel_uri,rel_pop)),columns=(rel_col)).drop_duplicates(subset=['name'],keep='first')
    
    print('<DataFrame completed>')
    print('\n---------------------------------------------------------------------------------\n')
        
    return rel_df

# %% [markdown]
# - so, we use the previous function to obtain the DataFrame from which we want to get the suggested artists.

# %%
# sweet children's example
df = playlist_to_artists_df('https://open.spotify.com/playlist/0tLuWKIJqwMwj1RGSxZYYS?si=qoMitK0tQ46OLV56HJR2Mw')
# Out:
# name:  sweet children's
# public:  True
# collaborative:  False
# description:  Number of different artists: 7-------- Billie Joe Armstrong&#x2F;Foxboro Hottubs&#x2F;Green Day&#x2F;Pinhead Gunpowder&#x2F;The Longshot&#x2F;The Network&#x2F;U2
# followers:  0
#
# ---------------------------------------------------------------------------------
#
# <DataFrame completed>
#
# ---------------------------------------------------------------------------------

# %%
rel_df = artist_df_suggested_artists_df(df)
rel_df
# Out:
# <DataFrame completed>
#
# ---------------------------------------------------------------------------------
#                      name                                             genres  \
# 0             The Network                                   [bay area indie]
# 1       Pinhead Gunpowder                          [orgcore, power-pop punk]
# 2    Billie Joe Armstrong                                                 []
# 3         Foxboro Hottubs                                   [bay area indie]
# 4        The Interrupters                  [punk, ska, ska punk, skate punk]
# ..                    ...                                                ...
# 135                 James  [britpop, dance rock, madchester, new wave, ne...
# 136           Men At Work  [album rock, australian rock, dance rock, mell...
# 137                  a-ha  [dance rock, new romantic, new wave, new wave ...
# 138            Eurythmics  [art rock, dance pop, dance rock, europop, mel...
# 139              The Cure  [dance rock, new romantic, new wave, permanent...
#
#                                        uri  popularity
# 0    spotify:artist:0vDdlaPkN2w0ibESVsrI3F          49
# 1    spotify:artist:3FV6RFbfc6do1nCakWsNBx          28
# 2    spotify:artist:1MrEurzLcL8ugfP1PrUPWG          57
# 3    spotify:artist:5tI0Vj2FhioY8AKtEqu9d3          35
# 4    spotify:artist:25Maank76ry2Tmbi2Ql1SF          58
# ..                                     ...         ...
# 135  spotify:artist:0qLNsNKm8bQcMoRFkR8Hmh          62
# 136  spotify:artist:0f3EsoviYnRKTkmayI3cux          67
# 137  spotify:artist:2jzc5TC5TVFLXQlBNiIUzE          72
# 138  spotify:artist:0NKDgy9j66h3DLnN8qu1bB          70
# 139  spotify:artist:7bu3H8JO7d0UbMoVzbo70s          76
#
# [91 rows x 4 columns]

# %% [markdown]
# - now, we can also use the available info to filter the results as we want.

# %%
# example only if popularity is >= 70
rel_df[rel_df['popularity']>=70].sort_values('popularity',ascending=False)
# Out:
#                          name  \
# 44                  Green Day
# 108                 blink-182
# 111       My Chemical Romance
# 122                The Police
# 103             The Offspring
# 139                  The Cure
# 120                    R.E.M.
# 118              Rise Against
# 100                    Sum 41
# 123                Pretenders
# 125           Tears For Fears
# 126             Lenny Kravitz
# 132                Billy Idol
# 137                      a-ha
# 104               Simple Plan
# 106  The All-American Rejects
# 124                      INXS
# 127               Duran Duran
# 138                Eurythmics
#
#                                                 genres  \
# 44                    [permanent wave, pop punk, punk]
# 108                   [pop punk, punk, socal pop punk]
# 111                                    [emo, pop punk]
# 122  [album rock, art rock, classic rock, dance roc...
# 103  [alternative metal, permanent wave, punk, rock...
# 139  [dance rock, new romantic, new wave, permanent...
# 120  [alternative rock, classic rock, permanent wav...
# 118  [chicago hardcore, chicago punk, hardcore punk...
# 100  [alternative metal, canadian pop punk, canadia...
# 123  [album rock, art rock, classic rock, dance roc...
# 125  [dance rock, new romantic, new wave, new wave ...
# 126                   [permanent wave, pop rock, rock]
# 132  [album rock, classic rock, dance rock, hard ro...
# 137  [dance rock, new romantic, new wave, new wave ...
# 104  [canadian pop punk, canadian punk, canadian ro...
# 106      [modern rock, neo mellow, pop punk, pop rock]
# 124  [australian rock, classic rock, dance rock, fu...
# 127  [dance rock, new romantic, new wave, new wave ...
# 138  [art rock, dance pop, dance rock, europop, mel...
#
#                                        uri  popularity
# 44   spotify:artist:7oPftvlwr6VrsViSDV7fJY          82
# 108  spotify:artist:6FBDaR13swtiWwGhX1WQsP          79
# 111  spotify:artist:7FBcuc1gsnv6Y1nwFtNRCb          79
# 122  spotify:artist:5NGO30tJxFlKixkPSgXcFE          77
# 103  spotify:artist:5LfGQac0EIXyAN8aUwmNAQ          77
# 139  spotify:artist:7bu3H8JO7d0UbMoVzbo70s          76
# 120  spotify:artist:4KWTAlx2RvbpseOGMEmROg          75
# 118  spotify:artist:6Wr3hh341P84m3EI8qdn9O          73
# 100  spotify:artist:0qT79UgT5tY4yudH9VfsdT          73
# 123  spotify:artist:0GByy3DcfbQwDvXGCWmzv9          72
# 125  spotify:artist:4bthk9UfsYUYdcFyqxmSUU          72
# 126  spotify:artist:5gznATMVO85ZcLTkE9ULU7          72
# 132  spotify:artist:7lzordPuZEXxwt9aoVZYmG          72
# 137  spotify:artist:2jzc5TC5TVFLXQlBNiIUzE          72
# 104  spotify:artist:2p4FqHnazRucYQHyDCdBrJ          71
# 106  spotify:artist:3vAaWhdBR38Q02ohXqaNHT          70
# 124  spotify:artist:1eClJfHLoDI4rZe5HxzBFv          70
# 127  spotify:artist:0lZoBs4Pzo7R89JM9lxwoT          70
# 138  spotify:artist:0NKDgy9j66h3DLnN8qu1bB          70

# %%
# example only if popularity is <= 40 
rel_df[rel_df['popularity']<=40].sort_values('popularity',ascending=True)
# Out:
#                     name                                             genres  \
# 34            Ben Weasel                          [orgcore, power-pop punk]
# 6             Dookiefied                                                 []
# 27              J Church                          [orgcore, power-pop punk]
# 9             Armstrongs                                                 []
# 37             Parasites                                   [power-pop punk]
# 36           Crimpshrine                                          [orgcore]
# 38       The Vindictives                     [chicago punk, power-pop punk]
# 24        The Methadones            [chicago punk, orgcore, power-pop punk]
# 25            Teen Idols                                   [power-pop punk]
# 32      Groovie Ghoulies                                   [power-pop punk]
# 30           Chixdiggit!  [canadian pop punk, canadian punk, orgcore, po...
# 95               Ultra Q                                    [oakland indie]
# 29             The Ergs!  [folk punk, indie punk, new jersey hardcore, n...
# 28  The Mr. T Experience                          [orgcore, power-pop punk]
# 1      Pinhead Gunpowder                          [orgcore, power-pop punk]
# 26            Riverdales            [chicago punk, orgcore, power-pop punk]
# 22        The Copyrights  [melodic hardcore, orgcore, power-pop punk, sk...
# 39        Sloppy Seconds                    [power-pop punk, punk 'n' roll]
# 3        Foxboro Hottubs                                   [bay area indie]
# 31        Dillinger Four  [emo, folk punk, indie punk, melodic hardcore,...
# 91              Mt. Eddy       [indie garage rock, modern alternative rock]
# 33          The Longshot                                                 []
# 89      Laura Jane Grace             [acoustic punk, folk punk, indie punk]
#
#                                       uri  popularity
# 34  spotify:artist:0fh5OOocWI28CshnHH2UgI          12
# 6   spotify:artist:1iNFj9p5zDYyQyPz4YR3Et          13
# 27  spotify:artist:5cGuLuR5EH4Xj9KKZlcggT          17
# 9   spotify:artist:3DMwn9lJozTHbeI85XA08W          18
# 37  spotify:artist:35RN5R0bzXBOXsDEaYm3hP          18
# 36  spotify:artist:6OrO2mBKihDV9LK58mDZH2          19
# 38  spotify:artist:3CtpzRTXrYafkrOxka10ws          21
# 24  spotify:artist:2vbIY8Y2HJpomBP4a06AEB          23
# 25  spotify:artist:0SWH7zYU8XWVh14ig49fQH          24
# 32  spotify:artist:46PqexcuFAphFVDvw3V2BZ          25
# 30  spotify:artist:5ttkgHyn4qW2qktFws8IlD          27
# 95  spotify:artist:57JelvPHs2P6BROjeHhHZ3          27
# 29  spotify:artist:0DWMLvlNTK198Lq3wUwkVN          28
# 28  spotify:artist:3X5CCGAfbZKLPHnfMxc3Lp          28
# 1   spotify:artist:3FV6RFbfc6do1nCakWsNBx          28
# 26  spotify:artist:2R1M7IlF0xmkvrvfJ6e5Z9          29
# 22  spotify:artist:7xm2IaaRIe82EpyZwEi7Un          29
# 39  spotify:artist:3G9m3ClSpLacKONiGjFvHA          30
# 3   spotify:artist:5tI0Vj2FhioY8AKtEqu9d3          35
# 31  spotify:artist:4YAN46l70QV0PGXlMg0iHi          36
# 91  spotify:artist:5gtaNT5WUXaEQsD0wyCKiq          37
# 33  spotify:artist:6MBlO0toUKQKFi5g0z4u3O          38
# 89  spotify:artist:4yfPiAauSgUfyc4k4WtwM9          40

# %% [markdown]
# - now, we have a DataFrame of suggested artists, maybe can be usefull also obtaining some of their most famous tracks.

# %% [markdown]
# ## top_tracks
# - This is the basic function to obtain the top tracks of an artist. Then, the function will be developed in such a way to receive as input a DataFrame of artists.

# %%
def top_tracks(artist, country, number_of_tracks):
    """ Get Spotify catalog information about an artist’s top 10 tracks by country.

    Parameters
    ----------
    artist : str
        uri/url/ID of the objective artist.
    country : str
        ex. 'US' in order to list the top tracks limiting the response to one particular country

    Returns
    -------
    None.

    """
    print('The objective aritst is: '+sp.artist(artist)['name'],'\n')
    
    for i in range(number_of_tracks):
        print('({}):'.format(i+1),sp.artist_top_tracks(artist,country=country)['tracks'][i]['name'])
        print('album: {}'.format(sp.artist_top_tracks(artist,country=country)['tracks'][i]['album']['name']))
        print('--------------\n')
        
    return None

# %%
# arctic example
top_tracks('spotify:artist:7Ln80lUS6He07XvHI8qqHH', 'IT', 7)
# Out:
# The objective aritst is: Arctic Monkeys
#
# (1): Do I Wanna Know?
# album: AM
# --------------
#
# (2): Why'd You Only Call Me When You're High?
# album: AM
# --------------
#
# (3): I Wanna Be Yours
# album: AM
# --------------
#
# (4): R U Mine?
# album: AM
# --------------
#
# (5): 505
# album: Favourite Worst Nightmare
# --------------
#
# (6): Fluorescent Adolescent
# album: Favourite Worst Nightmare
# --------------
#
# (7): Arabella
# album: AM
# --------------

# %% [markdown]
# ## artists_df_top_tracks_df
# - This function takes as input a DataFrame of different artists and returns their top tracks.

# %%
def artists_df_top_tracks_df(df, country, number_of_tracks):
    """ From a df containing information of different artists, this function, suggests for every artist 
    dataframe of their top tracks according to spotify, limiting the response to one particular country.  
    
    Parameters
    ----------
    df : pd.DataFrame(containing the columns 'artist' & 'uri')
        iterable containing the uris/urls of the artists
        'spotify:artist:INSERT_HERE_SPECIFIC_URI_CODE'.
    country : str
        ex. 'US' in order to list the top tracks limiting the response to one particular country.
    number_of_tracks : int
        choose the number of top tracks to return for each artist.

    Returns
    -------
    top_tracks_df: pd.DataFrame
        DataFrame of the top tracks.

    """
    
    artist_name = []
    track_position = []
    track_name = []
    album_name = []
    uris = []
    col_name = ['artist','position','track','album','uri']
    
    artist_to_analyze = df['uri']
    
    for uri in artist_to_analyze:
        for i in range(number_of_tracks):
            artist_name.append(sp.artist(uri)['name'])
            track_position.append('({})'.format(i+1))
            track_name.append(sp.artist_top_tracks(uri,country=country)['tracks'][i]['name'])
            album_name.append(sp.artist_top_tracks(uri,country=country)['tracks'][i]['album']['name'])
            uris.append(sp.artist(uri)['uri'])
            
    top_tracks_df = pd.DataFrame(list(zip(artist_name, track_position, track_name, album_name, uris)),columns=(col_name))
    top_tracks_df = top_tracks_df.drop_duplicates(subset=['track'],keep='first')
    
    
    print('<DataFrame completed>')
    print('\n---------------------------------------------------------------------------------\n')
        
    return top_tracks_df

# %%
# the adults are talking example
df = playlist_to_artists_df('https://open.spotify.com/playlist/2rQTtxMfmdrQOWHeEbStwM')
top_tracks_df = artists_df_top_tracks_df(df, 'IT', 3)
# Out:
# name:  the adults are talking
# public:  True
# collaborative:  False
# description:  You are saying all the words I&#x27;m dreaming--------Number of different artists: 72
# followers:  7
#
# ---------------------------------------------------------------------------------
#
# <DataFrame completed>
#
# ---------------------------------------------------------------------------------
#
# <DataFrame completed>
#
# ---------------------------------------------------------------------------------

# %%
top_tracks_df
# Out:
#                  artist position  \
# 0        Arctic Monkeys      (1)
# 1        Arctic Monkeys      (2)
# 2        Arctic Monkeys      (3)
# 3     Cage The Elephant      (1)
# 4     Cage The Elephant      (2)
# ..                  ...      ...
# 211  The Rolling Stones      (2)
# 212  The Rolling Stones      (3)
# 213        Rino Gaetano      (1)
# 214        Rino Gaetano      (2)
# 215        Rino Gaetano      (3)
#
#                                             track  \
# 0                                Do I Wanna Know?
# 1        Why'd You Only Call Me When You're High?
# 2                                I Wanna Be Yours
# 3                             Cigarette Daydreams
# 4                                         Trouble
# ..                                            ...
# 211  (I Can't Get No) Satisfaction - Mono Version
# 212                      Start Me Up - Remastered
# 213                  Ma il cielo è sempre più blu
# 214                           Sfiorivano le viole
# 215                          A mano a mano - Live
#
#                              album                                    uri
# 0                               AM  spotify:artist:7Ln80lUS6He07XvHI8qqHH
# 1                               AM  spotify:artist:7Ln80lUS6He07XvHI8qqHH
# 2                               AM  spotify:artist:7Ln80lUS6He07XvHI8qqHH
# 3                       Melophobia  spotify:artist:26T3LtbuGT1Fu9m0eRq5X3
# 4               Tell Me I'm Pretty  spotify:artist:26T3LtbuGT1Fu9m0eRq5X3
# ..                             ...                                    ...
# 211               Out Of Our Heads  spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# 212  Tattoo You (2009 Re-Mastered)  spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# 213                      La Storia  spotify:artist:5RRPSRJpISAWEPOeSfYuhV
# 214   Mio Fratello E' Figlio Unico  spotify:artist:5RRPSRJpISAWEPOeSfYuhV
# 215   Rino Gaetano Live & Rarities  spotify:artist:5RRPSRJpISAWEPOeSfYuhV
#
# [216 rows x 5 columns]

# %% [markdown]
# - You are saying all the words I'm dreaming

# %%
for artist in set(top_tracks_df['uri']):
    top_tracks(artist, 'IT', 3)
# Out:
# The objective aritst is: The Smiths
#
# (1): There Is a Light That Never Goes Out - 2011 Remaster
# album: The Queen Is Dead
# --------------
#
# (2): This Charming Man - 2011 Remaster
# album: The Smiths
# --------------
#
# (3): How Soon Is Now? - 2011 Remaster
# album: Hatful of Hollow
# --------------
#
# The objective aritst is: The Muffs
#
# (1): Kids in America
# album: Hamburger
# --------------
#
# (2): Sad Tomorrow
# album: Blonder And Blonder
# --------------
#
# (3): Lucky Guy
# album: The Muffs
# --------------
#
# The objective aritst is: Modern Baseball
#
# (1): Your Graduation
# album: You're Gonna Miss It All
# --------------
#
# (2): Fine, Great
# album: You're Gonna Miss It All
# --------------
#
# (3): Tears Over Beers
# album: Sports
# --------------
#
# The objective aritst is: The Snuts
#
# (1): Juan Belmonte
# album: Juan Belmonte
# --------------
#
# (2): Elephants
# album: Elephants
# --------------
#
# (3): Always
# album: Always
# --------------
#
# The objective aritst is: The Smashing Pumpkins
#
# (1): 1979 - Remastered 2012
# album: Mellon Collie And The Infinite Sadness (Deluxe Edition)
# --------------
#
# (2): Bullet With Butterfly Wings - Remastered 2012
# album: Mellon Collie And The Infinite Sadness (Deluxe Edition)
# --------------
#
# (3): Tonight, Tonight - Remastered 2012
# album: Mellon Collie And The Infinite Sadness (Deluxe Edition)
# --------------
#
# The objective aritst is: The Clash
#
# (1): Should I Stay or Should I Go - Remastered
# album: Combat Rock (Remastered)
# --------------
#
# (2): London Calling - Remastered
# album: London Calling (Remastered)
# --------------
#
# (3): Rock the Casbah - Remastered
# album: Combat Rock (Remastered)
# --------------
#
# The objective aritst is: The Beach Boys
#
# (1): Little Saint Nick - 1991 Remix
# album: The Beach Boys' Christmas Album
# --------------
#
# (2): God Only Knows - Remastered
# album: Pet Sounds (Original Mono & Stereo Mix Versions)
# --------------
#
# (3): Wouldn't It Be Nice - Stereo Mix
# album: Pet Sounds (Original Mono & Stereo Mix Versions)
# --------------
#
# The objective aritst is: The Libertines
#
# (1): Don't Look Back into the Sun
# album: Don't Look Back into the Sun
# --------------
#
# (2): Can't Stand Me Now
# album: The Libertines
# --------------
#
# (3): Time for Heroes
# album: Up the Bracket
# --------------
#
# The objective aritst is: MGMT
#
# (1): Little Dark Age
# album: Little Dark Age
# --------------
#
# (2): Kids
# album: Oracular Spectacular
# --------------
#
# (3): Electric Feel
# album: Oracular Spectacular
# --------------
#
# The objective aritst is: Iggy Pop
#
# (1): The Passenger
# album: Lust For Life
# --------------
#
# (2): Lust For Life
# album: Lust For Life
# --------------
#
# (3): Real Wild Child (Wild One)
# album: Blah-Blah-Blah
# --------------
#
# The objective aritst is: Green Day
#
# (1): Basket Case
# album: Dookie
# --------------
#
# (2): American Idiot
# album: American Idiot
# --------------
#
# (3): Wake Me up When September Ends
# album: American Idiot
# --------------
#
# The objective aritst is: Mac DeMarco
#
# (1): Chamber Of Reflection
# album: Salad Days
# --------------
#
# (2): My Kind of Woman
# album: 2
# --------------
#
# (3): Freaking Out the Neighborhood
# album: 2
# --------------
#
# The objective aritst is: Alkaline Trio
#
# (1): Radio
# album: Maybe I'll Catch Fire
# --------------
#
# (2): Mercy Me
# album: Crimson
# --------------
#
# (3): Private Eye
# album: From Here to Infirmary
# --------------
#
# The objective aritst is: The Rolling Stones
#
# (1): Paint It, Black
# album: Aftermath
# --------------
#
# (2): (I Can't Get No) Satisfaction - Mono Version
# album: Out Of Our Heads
# --------------
#
# (3): Start Me Up - Remastered
# album: Tattoo You (2009 Re-Mastered)
# --------------
#
# The objective aritst is: The Vaccines
#
# (1): If You Wanna
# album: What Did You Expect from The Vaccines?
# --------------
#
# (2): I Always Knew
# album: Come Of Age
# --------------
#
# (3): All My Friends Are Falling In Love
# album: All My Friends Are Falling In Love
# --------------
#
# The objective aritst is: Hüsker Dü
#
# (1): Don't Want to Know If You Are Lonely
# album: Candy Apple Grey
# --------------
#
# (2): Something I Learned Today
# album: Zen Arcade
# --------------
#
# (3): Eight Miles High
# album: Eight Miles High / Makes No Sense at All (Single)
# --------------
#
# The objective aritst is: Afterhours
#
# (1): Non È Per Sempre
# album: Non È Per Sempre
# --------------
#
# (2): Voglio Una Pelle Splendida
# album: Hai Paura Del Buio?
# --------------
#
# (3): Quello Che Non C'è
# album: Quello Che Non C'è
# --------------
#
# The objective aritst is: Radiohead
#
# (1): Creep
# album: Pablo Honey
# --------------
#
# (2): Karma Police
# album: OK Computer
# --------------
#
# (3): High and Dry
# album: The Bends
# --------------
#
# The objective aritst is: Liam Gallagher
#
# (1): All You're Dreaming Of
# album: All You're Dreaming Of
# --------------
#
# (2): Once
# album: Why Me? Why Not. (Deluxe Edition)
# --------------
#
# (3): Wall of Glass
# album: As You Were (Deluxe Edition)
# --------------
#
# The objective aritst is: Alex Turner
#
# (1): Stuck on the puzzle
# album: Submarine - Original Songs From The Film By Alex Turner
# --------------
#
# (2): Piledriver waltz
# album: Submarine - Original Songs From The Film By Alex Turner
# --------------
#
# (3): It's hard to get around the wind
# album: Submarine - Original Songs From The Film By Alex Turner
# --------------
#
# The objective aritst is: The Lawrence Arms
#
# (1): The Slowest Drink at the Saddest Bar on the Snowiest Day in the Greatest City
# album: Buttsweat and Tears
# --------------
#
# (2): Last, Last Words
# album: Skeleton Coast
# --------------
#
# (3): The YMCA Down The Street From The Clinic
# album: Metropole (Deluxe Edition)
# --------------
#
# The objective aritst is: The Menzingers
#
# (1): I Don't Wanna Be An Asshole Anymore
# album: Rented World
# --------------
#
# (2): After the Party
# album: After The Party
# --------------
#
# (3): America (You're Freaking Me Out)
# album: Hello Exile
# --------------
#
# The objective aritst is: The Peawees
#
# (1): Walking Through My Hell
# album: Moving Target
# --------------
#
# (2): Alone Again Or
# album: Alone Again Or
# --------------
#
# (3): As Long as You Can Sleep
# album: Moving Target
# --------------
#
# The objective aritst is: The Cure
#
# (1): Friday I'm In Love
# album: Wish
# --------------
#
# (2): Boys Don't Cry
# album: Three Imaginary Boys
# --------------
#
# (3): Just Like Heaven
# album: Kiss Me, Kiss Me, Kiss Me
# --------------
#
# The objective aritst is: Tim Timebomb
#
# (1): She's Drunk All the Time
# album: Tim Timebomb and Friends
# --------------
#
# (2): Change That Song Mr. DJ
# album: Tim Timebomb and Friends
# --------------
#
# (3): Ooh La La
# album: Tim Timebomb and Friends
# --------------
#
# The objective aritst is: Against Me!
#
# (1): Thrash Unreal
# album: New Wave (U.S. Version)
# --------------
#
# (2): I Was a Teenage Anarchist
# album: White Crosses
# --------------
#
# (3): Pints of Guinness Make You Strong
# album: Reinventing Axl Rose
# --------------
#
# The objective aritst is: Oasis
#
# (1): Wonderwall - Remastered
# album: (What's The Story) Morning Glory? [Remastered]
# --------------
#
# (2): Don't Look Back in Anger - Remastered
# album: (What's The Story) Morning Glory? [Remastered]
# --------------
#
# (3): Champagne Supernova - Remastered
# album: (What's The Story) Morning Glory? [Remastered]
# --------------
#
# The objective aritst is: Richard Ashcroft
#
# (1): A Song For The Lovers
# album: Alone With Everybody
# --------------
#
# (2): Break The Night With Colour
# album: Keys To The World
# --------------
#
# (3): They Don't Own Me
# album: These People
# --------------
#
# The objective aritst is: Cage The Elephant
#
# (1): Cigarette Daydreams
# album: Melophobia
# --------------
#
# (2): Trouble
# album: Tell Me I'm Pretty
# --------------
#
# (3): Ain't No Rest For The Wicked - Original Version
# album: Cage The Elephant
# --------------
#
# The objective aritst is: Prozac+
#
# (1): Acida
# album: Acidoacida
# --------------
#
# (2): Angelo
# album: 3 Prozac+
# --------------
#
# (3): Betty Tossica
# album: Acidoacida
# --------------
#
# The objective aritst is: Kings of Convenience
#
# (1): Misread
# album: Riot On An Empty Street
# --------------
#
# (2): I'd Rather Dance With You
# album: Riot On An Empty Street
# --------------
#
# (3): Know How
# album: Riot On An Empty Street
# --------------
#
# The objective aritst is: Julian Casablancas
#
# (1): 11th Dimension
# album: Phrazes For The Young
# --------------
#
# (2): Christmas Treat
# album: Christmas Treat
# --------------
#
# (3): I'll Try Anything Once - Live From Electric Lady Studios for WRXP, New York
# album: Live From Electric Lady Studios/WRXP New York
# --------------
#
# The objective aritst is: The Replacements
#
# (1): Swingin Party - 2008 Remaster
# album: Tim (Expanded)
# --------------
#
# (2): Androgynous
# album: Let It Be (Expanded)
# --------------
#
# (3): Can't Hardly Wait - 2008 Remaster
# album: Pleased to Meet Me (Expanded)
# --------------
#
# The objective aritst is: The Fratellis
#
# (1): Chelsea Dagger
# album: Costello Music
# --------------
#
# (2): Whistle For The Choir
# album: Costello Music
# --------------
#
# (3): Henrietta
# album: Costello Music
# --------------
#
# The objective aritst is: Old Crow Medicine Show
#
# (1): Wagon Wheel
# album: O.C.M.S.
# --------------
#
# (2): This Train is Bound for Glory
# album: Woody Guthrie: At 100! (Live At The Kennedy Center)
# --------------
#
# (3): Methamphetamine
# album: Tennessee Pusher
# --------------
#
# The objective aritst is: Blur
#
# (1): Song 2 - 2012 Remaster
# album: Blur [Special Edition]
# --------------
#
# (2): Girls and Boys
# album: Blur: The Best Of
# --------------
#
# (3): Coffee and TV
# album: 13
# --------------
#
# The objective aritst is: The Hives
#
# (1): Hate To Say I Told You So
# album: Veni Vidi Vicious
# --------------
#
# (2): Tick Tick Boom
# album: The Black and White album
# --------------
#
# (3): Walk Idiot Walk
# album: Tyrannosaurus Hives
# --------------
#
# The objective aritst is: Bugo
#
# (1): Sincero (feat. Morgan)
# album: Cristian Bugatti
# --------------
#
# (2): Mi manca (feat. Ermal Meta)
# album: Cristian Bugatti
# --------------
#
# (3): Io Mi Rompo I Coglioni
# album: Dal Lofai Al Cisei
# --------------
#
# The objective aritst is: The Strumbellas
#
# (1): Spirits
# album: Hope
# --------------
#
# (2): Salvation
# album: Rattlesnake
# --------------
#
# (3): We Don't Know
# album: Hope
# --------------
#
# The objective aritst is: Joe Strummer
#
# (1): Mondo Bongo
# album: Global A Go-Go
# --------------
#
# (2): Johnny Appleseed
# album: Global A Go-Go
# --------------
#
# (3): Redemption Song
# album: Streetcore
# --------------
#
# The objective aritst is: Operation Ivy
#
# (1): Sound System - 2007 Remaster
# album: Operation Ivy (2007 Remaster)
# --------------
#
# (2): Knowledge - 2007 Remaster
# album: Operation Ivy (2007 Remaster)
# --------------
#
# (3): Take Warning - 2007 Remaster
# album: Operation Ivy (2007 Remaster)
# --------------
#
# The objective aritst is: Gorillaz
#
# (1): Feel Good Inc.
# album: Demon Days
# --------------
#
# (2): On Melancholy Hill
# album: Plastic Beach
# --------------
#
# (3): Clint Eastwood
# album: Gorillaz
# --------------
#
# The objective aritst is: PJ Harvey
#
# (1): This Mess We're In
# album: Stories From The City, Stories From The Sea
# --------------
#
# (2): Down By The Water
# album: To Bring You My Love
# --------------
#
# (3): Good Fortune
# album: Stories From The City, Stories From The Sea
# --------------
#
# The objective aritst is: The Gaslight Anthem
#
# (1): The '59 Sound
# album: The '59 Sound
# --------------
#
# (2): "45"
# album: Handwritten (Deluxe Version)
# --------------
#
# (3): Great Expectations
# album: The '59 Sound
# --------------
#
# The objective aritst is: Joy Division
#
# (1): Disorder - 2007 Remaster
# album: Unknown Pleasures (Collector's Edition)
# --------------
#
# (2): Love Will Tear Us Apart - 2020 Remaster
# album: Love Will Tear Us Apart
# --------------
#
# (3): She's Lost Control - 2007 Remaster
# album: Unknown Pleasures (Collector's Edition)
# --------------
#
# The objective aritst is: Jet
#
# (1): Are You Gonna Be My Girl
# album: Get Born
# --------------
#
# (2): Look What You've Done
# album: Get Born
# --------------
#
# (3): Cold Hard Bitch
# album: Get Born
# --------------
#
# The objective aritst is: Kaiser Chiefs
#
# (1): Ruby
# album: Yours Truly, Angry Mob
# --------------
#
# (2): I Predict A Riot
# album: Employment
# --------------
#
# (3): Everyday I Love You Less And Less
# album: Employment
# --------------
#
# The objective aritst is: The xx
#
# (1): Intro
# album: xx
# --------------
#
# (2): Angels
# album: Coexist
# --------------
#
# (3): Crystalised
# album: xx
# --------------
#
# The objective aritst is: IDLES
#
# (1): War
# album: Ultra Mono
# --------------
#
# (2): Never Fight A Man With A Perm
# album: Joy as an Act of Resistance.
# --------------
#
# (3): Grounds
# album: Ultra Mono
# --------------
#
# The objective aritst is: Arctic Monkeys
#
# (1): Do I Wanna Know?
# album: AM
# --------------
#
# (2): Why'd You Only Call Me When You're High?
# album: AM
# --------------
#
# (3): I Wanna Be Yours
# album: AM
# --------------
#
# The objective aritst is: Placebo
#
# (1): Every You Every Me
# album: Without You I'm Nothing
# --------------
#
# (2): The Bitter End
# album: Sleeping With Ghosts
# --------------
#
# (3): Running Up That Hill
# album: Covers
# --------------
#
# The objective aritst is: The Razorbacks
#
# (1): BB
# album: BB
# --------------
#
# (2): Mess
# album: Sometimes
# --------------
#
# (3): Octopiss Garden
# album: Sometimes
# --------------
#
# The objective aritst is: Pinhead Gunpowder
#
# (1): Life During Wartime
# album: Goodbye Ellston Avenue
# --------------
#
# (2): Big Yellow Taxi
# album: Jump Salty
# --------------
#
# (3): 2nd Street
# album: Compulsive Disclosure
# --------------
#
# The objective aritst is: Black Rebel Motorcycle Club
#
# (1): Spread Your Love
# album: B.R.M.C.
# --------------
#
# (2): Beat the Devil's Tattoo
# album: Beat the Devil's Tattoo (Deluxe Version)
# --------------
#
# (3): Whatever Happened To My Rock 'N' Roll (Punk Song)
# album: B.R.M.C.
# --------------
#
# The objective aritst is: Pixies
#
# (1): Where Is My Mind? - Remastered
# album: Surfer Rosa
# --------------
#
# (2): Here Comes Your Man
# album: Doolittle
# --------------
#
# (3): Hey
# album: Doolittle
# --------------
#
# The objective aritst is: The White Stripes
#
# (1): Seven Nation Army
# album: Elephant
# --------------
#
# (2): Fell In Love With a Girl
# album: White Blood Cells
# --------------
#
# (3): Icky Thump
# album: Icky Thump
# --------------
#
# The objective aritst is: The Network
#
# (1): Roshambo
# album: Money Money 2020 (U.S. PA Version)
# --------------
#
# (2): Theory Of Reality
# album: Money Money 2020 Pt II: We Told Ya So!
# --------------
#
# (3): Fentanyl
# album: Money Money 2020 Pt II: We Told Ya So!
# --------------
#
# The objective aritst is: Daft Punk
#
# (1): Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit
# album: Get Lucky (feat. Pharrell Williams & Nile Rodgers) [Radio Edit]
# --------------
#
# (2): Instant Crush (feat. Julian Casablancas)
# album: Random Access Memories
# --------------
#
# (3): One More Time
# album: Discovery
# --------------
#
# The objective aritst is: Rino Gaetano
#
# (1): Ma il cielo è sempre più blu
# album: La Storia
# --------------
#
# (2): Sfiorivano le viole
# album: Mio Fratello E' Figlio Unico
# --------------
#
# (3): A mano a mano - Live
# album: Rino Gaetano Live & Rarities
# --------------
#
# The objective aritst is: The Verve
#
# (1): Bitter Sweet Symphony
# album: Urban Hymns (Remastered 2016)
# --------------
#
# (2): Lucky Man
# album: Urban Hymns (Deluxe / Remastered 2016)
# --------------
#
# (3): The Drugs Don't Work
# album: Urban Hymns (Deluxe / Remastered 2016)
# --------------
#
# The objective aritst is: The Strokes
#
# (1): Reptilia
# album: Room On Fire
# --------------
#
# (2): The Adults Are Talking
# album: The New Abnormal
# --------------
#
# (3): Last Nite
# album: Is This It
# --------------
#
# The objective aritst is: Catfish and the Bottlemen
#
# (1): 7
# album: The Ride
# --------------
#
# (2): Kathleen
# album: The Balcony
# --------------
#
# (3): Cocoon
# album: The Balcony
# --------------
#
# The objective aritst is: Tame Impala
#
# (1): The Less I Know The Better
# album: Currents
# --------------
#
# (2): Borderline
# album: The Slow Rush
# --------------
#
# (3): Feels Like We Only Go Backwards
# album: Lonerism
# --------------
#
# The objective aritst is: The Beatles
#
# (1): Here Comes The Sun - Remastered 2009
# album: Abbey Road (Remastered)
# --------------
#
# (2): Come Together - Remastered 2009
# album: Abbey Road (Remastered)
# --------------
#
# (3): Let It Be - Remastered 2009
# album: Let It Be (Remastered)
# --------------
#
# The objective aritst is: The Subways
#
# (1): Rock & Roll Queen
# album: Young For Eternity
# --------------
#
# (2): Oh Yeah
# album: Young For Eternity (Japanese Version)
# --------------
#
# (3): I Want To Hear What You Have Got To Say
# album: Young For Eternity (Japanese Version)
# --------------
#
# The objective aritst is: The Killers
#
# (1): Mr. Brightside
# album: Hot Fuss
# --------------
#
# (2): When You Were Young
# album: Sam's Town
# --------------
#
# (3): Human
# album: Day & Age (Bonus Tracks)
# --------------
#
# The objective aritst is: The Lemonheads
#
# (1): Mrs. Robinson - Remastered
# album: It's A Shame About Ray (Expanded Edition)
# --------------
#
# (2): Into Your Arms
# album: Come On Feel The Lemonheads
# --------------
#
# (3): It's A Shame About Ray - Remastered
# album: It's A Shame About Ray (Expanded Edition)
# --------------
#
# The objective aritst is: Kasabian
#
# (1): Fire
# album: West Ryder Pauper Lunatic Asylum
# --------------
#
# (2): Underdog
# album: West Ryder Pauper Lunatic Asylum
# --------------
#
# (3): Club Foot
# album: Kasabian/Empire
# --------------
#
# The objective aritst is: Supergrass
#
# (1): Alright
# album: I Should Coco
# --------------
#
# (2): Tales of Endurance, Pt. 4, 5 & 6
# album: Road To Rouen
# --------------
#
# (3): Moving
# album: Supergrass
# --------------
#
# The objective aritst is: Phil Ochs
#
# (1): When I'm Gone
# album: There But For Fortune
# --------------
#
# (2): I Ain't Marching Anymore
# album: I Ain't Marching Anymore
# --------------
#
# (3): Draft Dodger Rag
# album: I Ain't Marching Anymore
# --------------
#
# The objective aritst is: BRONCHO
#
# (1): Class Historian
# album: Just Enough Hip to Be Woman
# --------------
#
# (2): Sandman
# album: Bad Behavior
# --------------
#
# (3): Get in My Car
# album: Bad Behavior
# --------------
#
# The objective aritst is: Nirvana
#
# (1): Smells Like Teen Spirit
# album: Nevermind (Deluxe Edition)
# --------------
#
# (2): Come As You Are
# album: Nevermind (Deluxe Edition)
# --------------
#
# (3): Heart-Shaped Box
# album: In Utero - 20th Anniversary - Deluxe Edition
# --------------
